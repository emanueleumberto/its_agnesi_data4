# %% [markdown]
# Utilizzando il dataset SerieA_Season2026.csv, analizzare le statistiche delle squadre della Serie A attraverso operazioni di raggruppamento (groupby), aggregazione e ordinamento dei dati con la libreria Pandas.
#
# Sei un Data Analyst che lavora per una redazione sportiva. Il tuo compito è estrarre statistiche significative dal campionato di Serie A 2025/2026 per creare report e classifiche.
#
# Il dataset contiene informazioni sulle 380 partite della stagione, tra cui:
#
# Squadra di casa (HomeTeam)
# Squadra ospite (AwayTeam)
# Gol segnati in casa (FTHG)
# Gol segnati in trasferta (FTAG)
# Risultato finale (FTR)
# Tiri effettuati (HS, AS)
# Tiri in porta (HST, AST)
# Falli (HF, AF)
# Cartellini gialli (HY, AY)
# Cartellini rossi (HR, AR)
#
# – Caricamento e Analisi Esplorativa
# Attività: Importare Pandas. Caricare il file CSV in un DataFrame.
# Visualizzare:
# - prime 5 righe;
# - dimensione del dataset;
# - elenco delle colonne;
# - informazioni generali tramite info().
#
# Output atteso
# Numero totale di partite.
# Numero di colonne.
# Tipologia dei dati presenti.
#
# – Gol segnati in casa
# Calcolare il totale dei gol segnati da ogni squadra nelle partite casalinghe.
#
# Attività
# - Raggruppare per HomeTeam.
# - Sommare la colonna FTHG.
# - Ordinare in ordine decrescente.
#
# Output atteso
# Squadra	    Gol Casa
# ...	        ...
# Domande
# Quale squadra ha segnato più gol in casa?
# Quale ne ha segnati meno?
#
# – Gol subiti in casa
# Anal casa.izzare la solidità difensiva delle squadre in
#
# Attività
# - Raggruppare per HomeTeam.
# - Sommare la colonna FTAG (gol subiti dalla squadra di casa).
# - Ordinare in ordine crescente.
#
# Domande
# Quale squadra ha subito meno gol in casa?
# Quale ne ha subiti di più?
#
# – Media gol segnati in casa
# Calcolare la produttività offensiva media.
#
# Attività
# - Raggruppare per HomeTeam.
# - Calcolare la media di FTHG.
# - Arrotondare il risultato a 2 decimali.
#
# Output atteso
# Squadra	    Media Gol Casa
# ...	        ...
#
# – Statistiche sui tiri
# Confrontare le squadre per capacità offensiva.
#
# Attività Calcolare per ogni squadra di casa:
# - numero medio di tiri (HS)
# - numero medio di tiri in porta (HST)
#
# Esempio
# Squadra	    Tiri Medi	Tiri in Porta Medi
# ...	        ...	        ...
#
# – Analisi disciplinare
# Valutare il comportamento delle squadre.
#
# Attività Per ogni squadra di casa calcolare:
# - totale cartellini gialli (HY)
# - totale cartellini rossi (HR)
#
# Output atteso
# Squadra	    Gialli	    Rossi
# ...	        ...	        ...
#
# Domande
# Quale squadra ha ricevuto più cartellini gialli?
# Quale squadra ha ricevuto più cartellini rossi?
#
# – Analisi multi-aggregazione
# Creare un report completo.
#
# Attività Per ogni squadra di casa calcolare:
# - gol segnati (somma)
# - gol segnati (media)
# - tiri medi
# - falli medi
#
# Utilizzare: groupby().agg()
# con più funzioni di aggregazione.
#
# Esempio
# Squadra	    Gol Totali	    Gol Medi	    Tiri Medi	    Falli Medi
# ...	        ...	            ...	            ...	            ...
#
# – Creazione classifica vittorie casalinghe
# Costruire una classifica delle squadre che vincono più partite in casa.
#
# Attività
# - Filtrare le partite con:
# - FTR == 'H'
# - Raggruppare per HomeTeam.
# - Contare il numero di vittorie.
#
# Output atteso
# Squadra	 Vittorie Casa
# ...	        ...

# %% [markdown]
# Analisi delle Vendite di una Catena di Negozi Online
#
# Una società di e-commerce ha raccolto i dati relativi agli ordini effettuati durante l'ultimo anno. Il dataset contiene informazioni su clienti, prodotti, quantità acquistate, prezzi, categorie merceologiche, città e date degli acquisti.
#
# Utilizzare il dataset: Ecommerce_Sales_Dataset.csv
#
# Prima di produrre report, è necessario verificare la qualità dei dati, correggere eventuali problemi e ricavare indicatori utili per il management.
#
# Esplorazione del dataset
# Attività
# - Caricare il dataset.
# - Visualizzare le prime e le ultime righe.
# - Analizzare struttura e tipologie dei dati.
# Domande
# - Quanti ordini sono presenti?
# - Quanti attributi descrivono ciascun ordine?
# - Esistono colonne che richiedono una conversione di tipo?
#
# Analisi dei valori mancanti
# Attività
# - Individuare eventuali valori nulli.
# Calcolare:
# - numero di valori mancanti per colonna;
# - percentuale di valori mancanti.
# Output richiesto
# Colonna	    Nulli	    Percentuale
# ...	        ...	        ...
# Domande
# - Quali colonne presentano più dati mancanti?
# - Quali strategie adotteresti per gestirli?
#
# Pulizia dei dati
# Attività
# - Creare una copia pulita del dataset.
# Regole
# - Eliminare colonne con oltre il 40% di valori mancanti.
# - Sostituire i valori nulli numerici con la mediana.
# - Sostituire i valori nulli testuali con: Sconosciuto
# Funzioni suggerite fillna() median() drop()
#
# Ricerca di anomalie
# Attività
# - Verificare la presenza di:
# - quantità negative;
# - prezzi uguali a zero;
# - sconti superiori al 100%;
# - sconti negativi.
# Esempio df[df["UnitPrice"] <= 0]
# Domande
# - Quali valori sono chiaramente errati?
# - Come potrebbero essere corretti?
#
# Gestione dei duplicati
# Attività
# - Controllare la presenza di ordini duplicati.
# Funzioni suggerite duplicated() drop_duplicates()
#
# Domande
# - Quanti record duplicati esistono?
# - La loro eliminazione modifica significativamente il dataset?
#
# Creazione di nuove variabili
# Attività
# - Creare le seguenti colonne.
#     Valore Lordo Ordine
#     GrossAmount = Quantity * UnitPrice
#     Valore Sconto
#     DiscountAmount = GrossAmount * Discount / 100
#     Valore Netto
#     NetAmount = GrossAmount - DiscountAmount
# Fascia di Spesa
# Importo Netto   	Fascia
# < 50 €	            Bassa
# 50-200 €	        Media
# > 200 €	            Alta
#
# Analisi descrittiva
# Attività
# - Calcolare:
#     fatturato totale;
#     valore medio degli ordini;
#     ordine più costoso;
#     ordine meno costoso;
#     deviazione standard del valore degli ordini.
# Domande
# - Qual è il fatturato complessivo?
# - Quanto spende mediamente un cliente per ordine?
#
# Analisi per categoria
# Attività
# - Calcolare per ogni categoria:
#     numero di ordini;
#     quantità totale venduta;
#     fatturato totale;
#     valore medio degli ordini.
# Funzioni suggerite groupby()    agg()
#
# Output richiesto
# Categoria	Ordini	Quantità	Fatturato	Ticket Medio
#
# Analisi geografica
# Attività
# - Calcolare per ogni città:
#     numero di ordini;
#     fatturato totale;
#     valore medio degli ordini.
# Domande
# - Quali sono le 10 città con il maggior fatturato?
# - Quali sono le 10 città con il minor fatturato?
#
# Analisi dei clienti
# Attività
# - Per ogni cliente calcolare:
#     numero di ordini;
#     spesa totale;
#     spesa media.
# Obiettivo
# Individuare i clienti più importanti.
#
# Output
# Cliente	Ordini	Spesa Totale	Spesa Media
